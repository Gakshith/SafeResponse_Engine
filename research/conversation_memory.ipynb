# %% [markdown]
# # Conversation Memory
#
# Stores recent chat turns and builds short memory context for follow-up questions.
#
# ## Source Files
# - `src/saferesponse_engine/components/conversation_memory.py`
# - `tests/test_conversation_memory.py`
# - `config/config.yaml`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from saferesponse_engine.config.configuration import ConfigurationManager
from saferesponse_engine.components.conversation_memory import ConversationMemoryLayer

config = ConfigurationManager().get_conversation_memory_config()
print(config)

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
