# %% [markdown]
# # Chat Engine Orchestration
#
# Connects chat intent routing, memory, pipeline execution, and API response formatting.
#
# ## Source Files
# - `src/saferesponse_engine/components/chat_engine.py`
# - `src/saferesponse_engine/components/conversation_memory.py`
# - `src/saferesponse_engine/serving/api.py`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from saferesponse_engine.components.chat_engine import SafeResponseChatEngine

engine = SafeResponseChatEngine()
engine.status()

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
