# %% [markdown]
# # Fine-Tuning Workflow
#
# SQuAD v2 conversion, supervised prompt format, LoRA training, and model registry tracking.
#
# ## Source Files
# - `scripts/prepare_squad_v2.py`
# - `scripts/finetune_model.py`
# - `data/squad_v2/finetune_train.jsonl`
# - `model_registry/registry.json`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from pathlib import Path
import json

path = Path('data/squad_v2/finetune_train.jsonl')
first = json.loads(path.read_text(encoding='utf-8').splitlines()[0])
first.keys()

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
