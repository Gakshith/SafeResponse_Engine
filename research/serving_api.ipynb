# %% [markdown]
# # Serving API
#
# FastAPI endpoints, persistent job/metrics state, request controls, and UI serving.
#
# ## Source Files
# - `src/saferesponse_engine/serving/api.py`
# - `src/saferesponse_engine/serving/state_store.py`
# - `tests/test_api.py`
# - `tests/test_state_store.py`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from saferesponse_engine.serving.state_store import APIStateStore

store = APIStateStore('/tmp/saferesponse-research-state.sqlite3')
store.metrics_summary()

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
