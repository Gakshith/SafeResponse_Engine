# %% [markdown]
# # Stage 7 - Final Output
#
# Formats the selected fusion decision into the user-facing final response.
#
# ## Source Files
# - `src/saferesponse_engine/components/final_output.py`
# - `src/saferesponse_engine/pipeline/stage_07_final_output.py`
# - `config/config.yaml`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from saferesponse_engine.config.configuration import ConfigurationManager
from saferesponse_engine.components.final_output import FinalOutputLayer

config = ConfigurationManager().get_final_output_config()
print(config)

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
