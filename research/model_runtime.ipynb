# %% [markdown]
# # Model Runtime
#
# Centralized model/tokenizer loading, offline behavior, runtime device selection, and LoRA adapter loading.
#
# ## Source Files
# - `src/saferesponse_engine/components/model_runtime.py`
# - `tests/test_model_runtime.py`
# - `config/config.yaml`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from saferesponse_engine.components.model_runtime import select_runtime, resolve_model_source

print(select_runtime())
print(resolve_model_source('Qwen/Qwen2.5-0.5B-Instruct', None))

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
