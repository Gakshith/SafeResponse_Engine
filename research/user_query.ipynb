# %% [markdown]
# # Stage 1 - User Query
#
# Captures a query and writes the Stage 1 query artifact used by retrieval.
#
# ## Source Files
# - `src/saferesponse_engine/components/user_query.py`
# - `src/saferesponse_engine/pipeline/stage_01_user_query.py`
# - `config/config.yaml`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from saferesponse_engine.config.configuration import ConfigurationManager
from saferesponse_engine.components.user_query import UserQuery

config = ConfigurationManager().get_user_query_config()
print(config)

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
