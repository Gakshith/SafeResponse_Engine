# %% [markdown]
# # Evaluation and Deployment
#
# Regression evaluation, Docker runtime expectations, and AWS deployment checks.
#
# ## Source Files
# - `scripts/run_evaluation.py`
# - `evaluation/examples.json`
# - `Dockerfile`
# - `docs/deployment_runbook.md`
# - `docs/evaluation.md`
#
# Use this notebook for research notes and experiments. Keep production logic in the source files listed above.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
import json
from pathlib import Path

examples = json.loads(Path('evaluation/examples.json').read_text())
len(examples), sorted({example['category'] for example in examples})

# %% [markdown]
# ## Research Notes
#
# - Add observations, experiments, and calibration notes here.
# - If an experiment should ship, move it into `src/`, `scripts/`, or `tests/`.
